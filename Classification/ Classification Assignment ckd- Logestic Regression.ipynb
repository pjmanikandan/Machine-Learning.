# %%
import pandas as pd

# %%
dataset=pd.read_csv("ckd.csv")
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)#get dummies is used to catogorical data handeling and changed numeric data by one hot encoding finaly is gives dummies so droup_first=True is delete first dummie colum
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
inde=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dep=dataset[['classification_yes']]

# %%
inde.shape
# Out:
# (399, 27)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(inde,dep,test_size=1/3,random_state=0)

# %%
dataset["classification_yes"].value_counts()
# Out:
# 1    249
# 0    150
# Name: classification_yes, dtype: int64

# %%
dataset.shape
# Out:
# (399, 28)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
param_grid={'solver':['newton-cg','lbfgs','liblinear','saga','sag'],'penalty':['l2']}
grid=GridSearchCV(LogisticRegression(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# C:\Users\PJ MANI\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'penalty': ['l2'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'saga',
#                                     'sag']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,grid_predictions)

# %%
cm
# Out:
# array([[49,  2],
#        [ 0, 82]], dtype=int64)

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        51
#            1       0.98      1.00      0.99        82
#
#     accuracy                           0.98       133
#    macro avg       0.99      0.98      0.98       133
# weighted avg       0.99      0.98      0.98       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9992826398852224

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_penalty  \
# 0       0.753103      0.356758         0.015624        0.009882            l2
# 1       0.143745      0.092382         0.000000        0.000000            l2
# 2       0.040621      0.025389         0.006251        0.007656            l2
# 3       0.049997      0.030297         0.009375        0.007654            l2
# 4       0.021874      0.007652         0.009376        0.007655            l2
#
#   param_solver                                    params  split0_test_score  \
# 0    newton-cg  {'penalty': 'l2', 'solver': 'newton-cg'}           0.981569
# 1        lbfgs      {'penalty': 'l2', 'solver': 'lbfgs'}           0.869648
# 2    liblinear  {'penalty': 'l2', 'solver': 'liblinear'}           0.981569
# 3         saga       {'penalty': 'l2', 'solver': 'saga'}           0.486532
# 4          sag        {'penalty': 'l2', 'solver': 'sag'}           0.486532
#
# ...

# %%
age=float(input("Age:"))
bp=float(input("BP:"))
al=float(input("AL:"))
su=float(input("SU:"))
bgr=float(input("BGR:"))
bu=float(input("BU:"))
sc=float(input("SC:"))
sod=float(input("SOD:"))
pot=float(input("POT:"))
hrmo=float(input("HRMO:"))
pcv=float(input("PCV:"))
wc=float(input("WC:"))
rc=float(input("RC:"))
sg_b=float(input("SG_B 1 or 0:"))
sg_c=float(input("SG_C 1 or 0:"))
sg_d=float(input("SG_D 1 or 0:"))
sg_e=float(input("SG_E 1 or 0:"))
rbc_normal=float(input("RBC Normal 0 or 1:"))
pc_normal=float(input("PC Normal 0 or 1:"))
pcc_present=float(input("PC Present 0 or 1:"))
ba_present=float(input("BA_Present 0 or 1:"))
htn_yes=float(input("HTN 0 or 1:"))
dm_yes=float(input("DM 0 or 1:"))
cad_yes=float(input("CAD 0 or 1:"))
appet_yes=float(input("Appet 0 or 1:"))
pe_yes=float(input("PE 0 or 1:"))
ane_yes=float(input("ANE 0 or 1:"))
# Out:
# Age:10
# BP:75
# AL:1.0
# SU:0.0
# BGR:200
# BU:100
# SC:5.0
# SOD:130
# POT:5.2
# HRMO:17
# PCV:35
# WC:800
# RC:4.9
# SG_B 1 or 0:0
# SG_C 1 or 0:0
# SG_D 1 or 0:0
# SG_E 1 or 0:0
# RBC Normal 0 or 1:1
# PC Normal 0 or 1:0
# PC Present 0 or 1:1
# BA_Present 0 or 1:0
# HTN 0 or 1:0
# DM 0 or 1:1
# CAD 0 or 1:0
# Appet 0 or 1:1
# PE 0 or 1:0
# ANE 0 or 1:0

# %%
Result=grid.predict([[age,bp, al, su, bgr, bu, sc, sod, pot, hrmo, pcv,
       wc, rc, sg_b, sg_c, sg_d, sg_e, rbc_normal, pc_normal,
       pcc_present, ba_present, htn_yes, dm_yes, cad_yes,
       appet_yes, pe_yes, ane_yes]])
# Out:
# C:\Users\PJ MANI\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(Result)
# Out:
# [1]
